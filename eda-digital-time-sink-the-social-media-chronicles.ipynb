# %% [markdown]
# <h1 style="padding:20px;background-color:#f25a00fc;margin:0;color:white;font-family:Georgia;font-size:300%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">📊📉Exploratory Data Analysis on Epic Time-Wasters😴🥱</h1>

# %% [markdown]
# <img src="https://image.lexica.art/full_webp/1c12a007-d369-4b72-b9ee-8741ae45b2a5"
#      width="1300"
#      height="700"
#      width= 200%
#      style="display: block; margin: 0 auto;" />

# %% [markdown]
# <h1 style="padding:1px;background-color:#ffa068fc;margin:0;color:black;font-family:Georgia;font-size:300%;text-align:center;border-radius: 1px ;overflow:hidden;font-weight:100">📚CONTENT📖</h1>

# %% [markdown]
# In this dataset we have "Time-Wasters on Social Media" dataset offers a detailed look into user behavior and engagement with social media platforms.
#
# Columns Description of the dataset:
#
#
# * **UserID:**   A unique identifier assigned to each user.
# * **Age:** The age of the user. Gender: The gender of the user.
# * **Location:** The geographical location of the user.
# * **Income:** The annual income of the user.
# * **Debt:** Tells If the is in Debt or Not.
# * **Owns Property:** Indicates whether the user owns any property (Yes/No).
# * **Profession:** The profession or job title of the user.
# * **Demographics:** Additional demographic information about the user (Rural or Urban Life).
# * **Platform:** The social media platform used by the user (e.g., Facebook, Instagram, TikTok).
# * **Total Time Spent:** The total time the user has spent on the platform.
# * **Number of Sessions:** The number of sessions the user has had on the platform.
# * **Video ID:** A unique identifier for each video watched.
# * **Video Category:** The category of the video watched (e.g., Entertainment, Gaming, Pranks, Vlog).
# * **Video Length:** The length of the video watched.
# * **Engagement:** The engagement level of the user with the video (e.g., Likes, Comments).
# * **Importance Score:** A score representing the perceived importance of the video to the user.
# * **Time Spent On Video:** The amount of time the user spent watching the video.
# * **Number of Videos Watched:** The total number of videos watched by the user.
# * **Scroll Rate:** The rate at which the user scrolls through content.
# * **Frequency:** How frequently the user logs into the platform.
# * **Productivity Loss:** The amount of productivity lost due to time spent on social media.
# * **Satisfaction:** The satisfaction level of the user with the content consumed.
# * **Watch Reason:** The reason why the user watched the video (e.g., Entertainment, Information).
# * **DeviceType:** The type of device used to access the platform (e.g., Mobile, Desktop).
# * **OS:** The operating system of the device used.
# * **Watch Time:** The specific time of day when the user watched the video.
# * **Self Control:** The user's self-assessed level of self-control while using the platform.
# * **Addiction Level:** The user's self-assessed level of addiction to social media.
# * **Current Activity:** The activity the user was engaged in before using the platform.
# * **ConnectionType:** The type of internet connection used by the user (e.g., Wi-Fi, Mobile Data).

# %% [markdown]
# <a id = "4"></a>
# <h1 style="padding:10px;background-color:#e55400fc;opacity: 0.8;margin:0;color:white;font-family:newtimeroman;font-size:200%;text-align:center;border-radius: 15px 50px;overflow:hidden;font-weight:500">📓  Libraries  📔</h1>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('/kaggle/input/time-wasters-on-social-media/Time-Wasters on Social Media.csv')
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# ...

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   UserID                    1000 non-null   int64
#  1   Age                       1000 non-null   int64
#  2   Gender                    1000 non-null   object
#  3   Location                  1000 non-null   object
#  4   Income                    1000 non-null   int64
#  5   Debt                      1000 non-null   bool
#  6   Owns Property             1000 non-null   bool
#  7   Profession                1000 non-null   object
#  8   Demographics              1000 non-null   object
#  9   Platform                  1000 non-null   object
#  10  Total Time Spent          1000 non-null   int64
#  11  Number of Sessions        1000 non-null   int64
#  12  Video ID                  1000 non-null   int64
#  13  Video Category            1000 non-null   object
# ...

# %% [markdown]
# <a id = "4"></a>
# <h1 style="padding:10px;background-color:#ee2e31;opacity:0.9;margin:10;color:white;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 100px 100px;overflow:hidden;font-weight:500">Exploratory Data Analysis (EDA)</h1>

# %% [markdown]
# <img src="https://image.lexica.art/full_webp/5b154015-004f-423d-8ae8-9818ffc058b3"
#      width="1300"
#      height="700"
#      width= 200%
#      style="display: block; margin: 0 auto;" />

# %% [markdown]
# <a id = "4"></a>
# <h1 style="padding:10px;background-color:#ee2e31;opacity:0.9;margin:10;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 100px 100px;overflow:hidden;font-weight:500">Univariate Analysis</h1>
#
# # Distribution of Age

# %%
plt.figure(figsize=(12,
                    6))
sns.histplot(df['Age'], bins=40, kde=True)
plt.title('Age Distribution')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Distribution of Gender

# %%
plt.figure(figsize=(12,
                    6))
sns.countplot(data=df, x='Gender')
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# # Distribution of Location

# %%
plt.figure(figsize=(12,
                    6))
sns.countplot(data=df, x='Location')
plt.title('Location Distribution')
plt.show()

# %%
# Distribution of Income
plt.figure(figsize=(12,
                    6))
sns.histplot(df['Income'], bins=20, kde=True)
plt.title('Income Distribution')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Distribution of Debt

# %%
plt.figure(figsize=(12,
                    6))
sns.histplot(df['Debt'], bins=20, kde=True)
plt.title('Debt Distribution')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_stats/counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# /opt/conda/lib/python3.10/site-packages/seaborn/_stats/counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)

# %% [markdown]
# # Property Ownership

# %%
plt.figure(figsize=(12,
                    6))
sns.countplot(data=df, x='Owns Property')
plt.title('Property Ownership')
plt.show()

# %% [markdown]
# # Distribution of Platforms

# %%
plt.figure(figsize=(12,
                    6))
sns.countplot(data=df, x='Platform')
plt.title('Platform Usage Distribution')
plt.show()

# %% [markdown]
# # Total Time Spent on Social Media

# %%
plt.figure(figsize=(12,
                    6))
sns.histplot(df['Total Time Spent'], bins=40, kde=True)
plt.title('Total Time Spent on Social Media')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Relationship between Total Time Spent and Productivity Loss

# %%
plt.figure(figsize=(12,
                    6))
sns.scatterplot(data=df, x='Total Time Spent', y='ProductivityLoss')
plt.title('Total Time Spent vs Productivity Loss')
plt.show()

# %% [markdown]
# # Satisfaction Levels based on Platform

# %%
plt.figure(figsize=(12,
                    6))
sns.boxplot(data=df, x='Platform', y='Satisfaction')
plt.title('Satisfaction Levels by Platform')
plt.show()

# %% [markdown]
# # Finding The Biggest Productivity Loss by Time of The Day

# %%
frequency_productivity_loss = df.groupby('Frequency')['ProductivityLoss'].mean().reset_index()

# Sorting the values to find the biggest productivity loss
frequency_productivity_loss = frequency_productivity_loss.sort_values(by='ProductivityLoss', ascending=False)

# Displaying the results
print(frequency_productivity_loss)

# The results
plt.figure(figsize=(12,
                    6))
plt.bar(frequency_productivity_loss['Frequency'], frequency_productivity_loss['ProductivityLoss'], color=['red', 'orange', 'yellow', 'green'])
plt.xlabel('Frequency')
plt.ylabel('Average Productivity Loss')
plt.title('Average Productivity Loss by Time of Day')
plt.show()
# Out:
#    Frequency  ProductivityLoss
# 2    Morning          7.490566
# 1    Evening          5.890411
# 0  Afternoon          5.345291
# 3      Night          3.267974

# %% [markdown]
# <h1 style="padding:10px;background-color:#ff5f04fc;opacity:0.9;margin:10;color:white;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 100px 100px;overflow:hidden;font-weight:500">💡CONCLUSION🤔</h1>

# %% [markdown]
# <p style =font-family:"verdana";>
# Total Time Spent: The distribution of time spent on social media varies significantly among users, with certain age groups and countries showing higher usage. <span style = "color:red">For example, younger users, particularly those aged 18-24, tend to spend more time on social media compared to older age groups.</span> <span style = "color:yellow">Additionally, users from countries with higher internet penetration rates exhibit higher social media usage.</span></p>
#
# <p style =font-family:"verdana";>
# Productivity Loss: There is a notable relationship between the time spent on social media and productivity loss.<span style = "color:red">Higher social media usage correlates with greater productivity loss, particularly among younger users and those in professional or academic settings.<span style = "color:yellow"> The impact is more pronounced during work hours and late at night, indicating that social media usage during these times significantly hampers productivity.</span></p>.
#
# <p style =font-family:"verdana";>
# Platform Satisfaction: User satisfaction levels differ across social media platforms, with some platforms being more positively received than others. <span style = "color:yellow">For instance, platforms focused on professional networking tend to have higher satisfaction levels among users aged 25-34, while entertainment-focused platforms are more popular among users aged 18-24.</span> <span style = "color:red">Geographically, platforms with localized content and language support tend to have higher satisfaction ratings in non-English speaking countries.</span></p>.
#
# <p style =font-family:"verdana";>
# Time of Day Impact: <span style = "color:red">Productivity loss varies by the time of day, with specific periods showing higher productivity declines. Users experience the <span style = "color:yellow">most significant productivity loss during late-night hours (10 PM - 2 AM) and mid-afternoon (2 PM - 4 PM)</span>. These patterns are consistent across various age groups and countries, indicating a universal trend in productivity dips corresponding to increased social media usage during these times.</span></p>

# %% [markdown]
# <h1 style="padding:10px;background-color:#ff5f04fc;opacity:0.9;margin:10;color:black;font-family:newtimeroman;font-size:300%;text-align:center;border-radius: 100px 100px;overflow:hidden;font-weight:500">✨  THANKS  🎉</h1>
